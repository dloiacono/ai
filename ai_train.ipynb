# %% [markdown]
# <a href="https://colab.research.google.com/github/dloiacono/ai/blob/main/ai_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import requests
import os
import json

# Mount Google Drive
drive.mount('/gdrive')

# Function to download PDF from a URL
def download_pdf(url, folder, uuid):
    filename = os.path.join(folder, f"{uuid}.pdf")
    with open(filename, 'wb') as f:
        f.write(requests.get(url).content)

# Function to download metadata for an item
def download_metadata(uuid, folder):
    url = f"https://publ.iss.it/ITA/Items/GetMetadata?uuid={uuid}"
    response = requests.get(url)
    metadata = response.json()
    with open(os.path.join(folder, f"{uuid}.json"), 'w') as f:
        f.write(json.dumps(metadata, indent=4))

# Function to download PDFs and metadata for a given year
def download_pdfs_and_metadata_for_year(year, folder):
    page = 1
    while True:
        # Construct URL for the given year and page
        url = f"https://publ.iss.it/ITA/Items/GetSearchResults?qualifier=year&value={year}&take=10&skip={10 * (page - 1)}&page={page}&pageSize=10"

        # Send a GET request to the URL
        response = requests.get(url)
        data = response.json()

        # Extract PDF links and UUIDs from JSON response
        items = data.get('docs', [])
        pdf_links = [item['bitstream'][0] for item in items if item.get('bitstream') and item['bitstream'][0] == 'true']
        uuids = [item['uuid'] for item in items if item.get('bitstream') and item['bitstream'][0] == 'true']

        # Download each PDF and metadata
        for pdf_link, uuid in zip(pdf_links, uuids):
            pdf_url = f"https://publ.iss.it/ITA/Items/GetPDF?uuid={uuid}"
            download_pdf(pdf_url, folder, uuid)
            print(f"Downloaded for {year} (Page {page}):", pdf_url)
            download_metadata(uuid, folder)
            print(f"Downloaded metadata for {year} (Page {page}):", uuid)

        # Check if there are more pages
        if len(items) < 10:
            break

        # Increment page number
        page += 1

# Set folder path where you want to save the PDFs and metadata
folder = '/gdrive/My Drive/AI/publiiss'

# Ensure the folder exists, otherwise create it
if not os.path.exists(folder):
    os.makedirs(folder)

# Iterate from current year to 2020 and download PDFs and metadata for each year
for year in range(2024, 2019, -1):
    download_pdfs_and_metadata_for_year(year, folder)

print("All PDFs and metadata downloaded successfully!")
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=84213128-a695-40b7-9616-cf7a5129a4b2
# Downloaded metadata for 2024 (Page 1): 84213128-a695-40b7-9616-cf7a5129a4b2
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=325546f4-4947-4650-92fa-483edd60326e
# Downloaded metadata for 2024 (Page 1): 325546f4-4947-4650-92fa-483edd60326e
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=9d2bbe48-d029-466d-a416-c2d63b7d119c
# Downloaded metadata for 2024 (Page 1): 9d2bbe48-d029-466d-a416-c2d63b7d119c
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=cd0ca97c-1fed-41f7-a3db-60031ec3835d
# Downloaded metadata for 2024 (Page 1): cd0ca97c-1fed-41f7-a3db-60031ec3835d
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=0de7b95b-2886-4ddd-bbfe-be1399798ebb
# Downloaded metadata for 2024 (Page 1): 0de7b95b-2886-4ddd-bbfe-be1399798ebb
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=c2a2207b-424a-4021-b941-25b9d355a365
# Downloaded metadata for 2024 (Page 1): c2a2207b-424a-4021-b941-25b9d355a365
# Downloaded for 2024 (Page 1): https://publ.iss.it/ITA/Items/GetPDF?uuid=a056c35e-7ca6-4e4e-8151-07b05fba1372
# Downloaded metadata for 2024 (Page 1): a056c35e-7ca6-4e4e-8151-07b05fba1372
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=7cbb9bd5-99d8-438d-9cfa-f46a451c625e
# Downloaded metadata for 2024 (Page 2): 7cbb9bd5-99d8-438d-9cfa-f46a451c625e
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=a42ea750-ee28-4813-b6ac-71113725da98
# Downloaded metadata for 2024 (Page 2): a42ea750-ee28-4813-b6ac-71113725da98
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=fc8c035f-b0b9-434b-a1b4-bb2dd2d48f3c
# Downloaded metadata for 2024 (Page 2): fc8c035f-b0b9-434b-a1b4-bb2dd2d48f3c
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=6b25a445-7375-4a48-9dd9-c28fa468f0bc
# Downloaded metadata for 2024 (Page 2): 6b25a445-7375-4a48-9dd9-c28fa468f0bc
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=12f34b99-d716-4328-b53c-e3a5296757e1
# Downloaded metadata for 2024 (Page 2): 12f34b99-d716-4328-b53c-e3a5296757e1
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=72892a6b-a363-424f-bdb0-62f79ab001bf
# Downloaded metadata for 2024 (Page 2): 72892a6b-a363-424f-bdb0-62f79ab001bf
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=06c0c69f-89c3-42ae-9b2f-2110ecc21a91
# Downloaded metadata for 2024 (Page 2): 06c0c69f-89c3-42ae-9b2f-2110ecc21a91
# Downloaded for 2024 (Page 2): https://publ.iss.it/ITA/Items/GetPDF?uuid=4c53f740-b4ea-4460-bd70-526f6dd7ccf4
# Downloaded metadata for 2024 (Page 2): 4c53f740-b4ea-4460-bd70-526f6dd7ccf4
# Downloaded for 2024 (Page 3): https://publ.iss.it/ITA/Items/GetPDF?uuid=fa8bace4-70e1-43e4-b5ec-cea9f55cb758
# Downloaded metadata for 2024 (Page 3): fa8bace4-70e1-43e4-b5ec-cea9f55cb758
# Downloaded for 2024 (Page 3): https://publ.iss.it/ITA/Items/GetPDF?uuid=2dcad160-7a8b-4247-b3d8-2dd0d00e4d35
# Downloaded metadata for 2024 (Page 3): 2dcad160-7a8b-4247-b3d8-2dd0d00e4d35
# Downloaded for 2024 (Page 3): https://publ.iss.it/ITA/Items/GetPDF?uuid=09e4529f-bcfb-4f99-ab0f-3eaa27b01f4b
# Downloaded metadata for 2024 (Page 3): 09e4529f-bcfb-4f99-ab0f-3eaa27b01f4b
# Downloaded for 2024 (Page 3): https://publ.iss.it/ITA/Items/GetPDF?uuid=9dddd294-e515-4cc0-9aa0-c96f8e8028c5
# Downloaded metadata for 2024 (Page 3): 9dddd294-e515-4cc0-9aa0-c96f8e8028c5
# Downloaded for 2024 (Page 3): https://publ.iss.it/ITA/Items/GetPDF?uuid=405ab746-ebc7-4871-8447-24e6a5084d3d
# Downloaded metadata for 2024 (Page 3): 405ab746-ebc7-4871-8447-24e6a5084d3d
# Downloaded for 2024 (Page 4): https://publ.iss.it/ITA/Items/GetPDF?uuid=73fb2064-c702-42fa-bd27-a52ee95f8125
# Downloaded metadata for 2024 (Page 4): 73fb2064-c702-42fa-bd27-a52ee95f8125
# Downloaded for 2024 (Page 4): https://publ.iss.it/ITA/Items/GetPDF?uuid=526608a3-4a39-4793-955c-f669dea2c38e
# Downloaded metadata for 2024 (Page 4): 526608a3-4a39-4793-955c-f669dea2c38e
# Downloaded for 2024 (Page 4): https://publ.iss.it/ITA/Items/GetPDF?uuid=8f22febc-9a6b-424e-8d11-164275517787
# Downloaded metadata for 2024 (Page 4): 8f22febc-9a6b-424e-8d11-164275517787
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=2f4a7ab2-b647-4ae5-82c4-cffe5f2241f4
# Downloaded metadata for 2024 (Page 5): 2f4a7ab2-b647-4ae5-82c4-cffe5f2241f4
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=571ee719-f286-48c9-8a0e-f06f7fc1110d
# Downloaded metadata for 2024 (Page 5): 571ee719-f286-48c9-8a0e-f06f7fc1110d
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=8f3f846e-7c0e-4211-94fa-9dcb0150bbeb
# Downloaded metadata for 2024 (Page 5): 8f3f846e-7c0e-4211-94fa-9dcb0150bbeb
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=d4668242-7a8a-4faa-b8a3-f44368c1b6d9
# Downloaded metadata for 2024 (Page 5): d4668242-7a8a-4faa-b8a3-f44368c1b6d9
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=e2727e5c-d18d-4292-a719-0d30681bbabc
# Downloaded metadata for 2024 (Page 5): e2727e5c-d18d-4292-a719-0d30681bbabc
# Downloaded for 2024 (Page 5): https://publ.iss.it/ITA/Items/GetPDF?uuid=e060ece9-e09e-47bf-abb4-64c1499dfffc
# Downloaded metadata for 2024 (Page 5): e060ece9-e09e-47bf-abb4-64c1499dfffc
# Downloaded for 2024 (Page 6): https://publ.iss.it/ITA/Items/GetPDF?uuid=e60f98c0-d5b9-457a-9681-dadfad613174
# Downloaded metadata for 2024 (Page 6): e60f98c0-d5b9-457a-9681-dadfad613174
# Downloaded for 2024 (Page 6): https://publ.iss.it/ITA/Items/GetPDF?uuid=3d6cca65-5a1b-41bd-9b59-ad4553a02440
# Downloaded metadata for 2024 (Page 6): 3d6cca65-5a1b-41bd-9b59-ad4553a02440
# Downloaded for 2024 (Page 6): https://publ.iss.it/ITA/Items/GetPDF?uuid=e0dd246c-3d98-4ba2-a9a5-6ee3d975a871
# Downloaded metadata for 2024 (Page 6): e0dd246c-3d98-4ba2-a9a5-6ee3d975a871
# Downloaded for 2024 (Page 6): https://publ.iss.it/ITA/Items/GetPDF?uuid=5a29a77c-a952-46aa-bb80-8a8578869b02
# Downloaded metadata for 2024 (Page 6): 5a29a77c-a952-46aa-bb80-8a8578869b02
# Downloaded for 2024 (Page 6): https://publ.iss.it/ITA/Items/GetPDF?uuid=af4ed120-01b0-45b2-b6ca-e30595762559
# Downloaded metadata for 2024 (Page 6): af4ed120-01b0-45b2-b6ca-e30595762559
